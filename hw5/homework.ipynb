# %% [markdown]
# # Домашнее задание  № 5. Матричные разложения/Тематическое моделирование

# %%
import gensim
import pandas as pd
import numpy as np
from pymorphy2 import MorphAnalyzer
from collections import Counter
from string import punctuation
from razdel import tokenize as razdel_tokenize
from IPython.display import Image
from IPython.core.display import HTML 
from sklearn.decomposition import TruncatedSVD, NMF, PCA, LatentDirichletAllocation
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.metrics.pairwise import cosine_distances
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, StratifiedKFold
import warnings
from matplotlib import pyplot as plt
import seaborn as sns
morph = MorphAnalyzer()
warnings.filterwarnings("ignore")
import pyLDAvis.gensim_models
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.datasets import make_classification
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Задание № 1 (4 балла)

# %% [markdown]
# Попробуйте матричные разложения с 5 классификаторами - SGDClassifier, KNeighborsClassifier,  RandomForest, ExtraTreesClassifier (про него подробнее почитайте в документации, он похож на RF). Используйте и NMF и SVD. Сравните результаты на кросс-валидации и выберите лучшее сочетание.
#
# В итоге у вас должно получиться, как минимум 10 моделей (два разложения на каждый классификатор). Используйте 1 и те же параметры кросс-валидации. Параметры векторизации, параметры K в матричных разложениях, параметры классификаторов могут быть разными между экспериментами.

# %% [markdown]
# Можете взять поменьше данных, если все будет обучаться слишком долго (не ставьте параметр K слишком большим в NMF, иначе точно будет слишком долго)

# %%
# лемматизация
def normalize(text):
    normalized_text = [word.text.strip(punctuation) for word \
                                                            in razdel_tokenize(text)]
    normalized_text = [word.lower() for word in normalized_text if word and len(word) < 20 ]
    normalized_text = [morph.parse(word)[0].normal_form for word in normalized_text]
    return ' '.join(normalized_text)

# %% [markdown]
# #### Работа с данными

# %%
data = pd.read_csv('avito_category_classification.csv')

# %%
data
# Out:
#                    category_name  \
# 0                     Автомобили
# 1         Детская одежда и обувь
# 2              Предложение услуг
# 3                     Автомобили
# 4                Бытовая техника
# ...                          ...
# 9893  Товары для детей и игрушки
# 9894      Детская одежда и обувь
# 9895   Одежда, обувь, аксессуары
# 9896      Детская одежда и обувь
# 9897             Бытовая техника
#
#                                             description
# 0               отличное состояние,обслужиание в салоне
# 1     В отличном состоянии. Фирма KIKO. Очень теплый...
# 2     Изготовление ограждений, перил,качелей, турник...
# 3     Автомобиль в отличном техническом состоянии. О...
# 4     Продается газовая плита "Гефест" (Белоруссия) ...
# ...                                                 ...
# 9893  Чтобы посмотреть весь ассортимент нашего магаз...
# 9894  Весна,осень.74-80.вопросы можно в вайбер,двухс...
# 9895  Кимоно Green Hill. Состояние  отличное,  рост ...
# 9896  Б/у кроссовки на девочку. Носили только в спор...
# 9897                            Холодильник на гарантии
#
# [9898 rows x 2 columns]

# %%
data['description_norm'] = data['description'].apply(normalize)

# %%
data
# Out:
#                    category_name  \
# 0                     Автомобили
# 1         Детская одежда и обувь
# 2              Предложение услуг
# 3                     Автомобили
# 4                Бытовая техника
# ...                          ...
# 9893  Товары для детей и игрушки
# 9894      Детская одежда и обувь
# 9895   Одежда, обувь, аксессуары
# 9896      Детская одежда и обувь
# 9897             Бытовая техника
#
#                                             description  \
# 0               отличное состояние,обслужиание в салоне
# 1     В отличном состоянии. Фирма KIKO. Очень теплый...
# 2     Изготовление ограждений, перил,качелей, турник...
# 3     Автомобиль в отличном техническом состоянии. О...
# 4     Продается газовая плита "Гефест" (Белоруссия) ...
# ...                                                 ...
# 9893  Чтобы посмотреть весь ассортимент нашего магаз...
# 9894  Весна,осень.74-80.вопросы можно в вайбер,двухс...
# 9895  Кимоно Green Hill. Состояние  отличное,  рост ...
# 9896  Б/у кроссовки на девочку. Носили только в спор...
# 9897                            Холодильник на гарантии
#
#                                        description_norm
# 0                отличный состояние обслужиание в салон
# 1     в отличный состояние фирма kiko очень тёплый у...
# 2     изготовление ограждение перила качели турников...
# 3     автомобиль в отличный технический состояние од...
# 4     продаваться газовый плита гефест белоруссия б ...
# ...                                                 ...
# 9893  чтобы посмотреть весь ассортимент наш магазин ...
# 9894  весна осень 74-80 вопрос можно в вайбер двухст...
# 9895  кимоно green hill состояние отличный рост 160-...
# 9896  б у кроссовок на девочка носить только в спортзал
# 9897                            холодильник на гарантия
#
# [9898 rows x 3 columns]

# %% [markdown]
# #### Функция classification report со встроенной кросс-валидацией

# %%
def eval_table(X, y, pipeline, N=6):
    # зафиксируем порядок классов
    labels = list(set(y))
    
    # метрики отдельных фолдов будет хранить в табличке
    fold_metrics = pd.DataFrame(index=labels)
    # дополнительно также соберем таблицу ошибок
    errors = np.zeros((len(labels), len(labels)))
    
    # создаем стратегию кросс-валидации
    # shuffle=True (перемешивание) - часто критично важно указать
    # т.к. данные могут быть упорядочены и модель на этом обучится
    kfold = StratifiedKFold(n_splits=N, shuffle=True, )
    
    for i, (train_index, test_index) in enumerate(kfold.split(X, y)):
        # fit-predict как и раньше, но сразу пайплайном
        pipeline.fit(X[train_index], y[train_index])
        preds = pipeline.predict(X[test_index])
        
        # записываем метрику и индекс фолда
        fold_metrics[f'precision_{i}'] = precision_score(y[test_index], preds, labels=labels, average=None)
        fold_metrics[f'recall_{i}'] = recall_score(y[test_index], preds, labels=labels, average=None)
        fold_metrics[f'f1_{i}'] = f1_score(y[test_index], preds, labels=labels, average=None)
        errors += confusion_matrix(y[test_index], preds, labels=labels, normalize='true')
    
    # таблица для усредненных значений
    # тут мы берем колонки со значениями и усредняем их
    # часто также все метрики сразу суммируют и в конце просто делят на количество фолдов
    # но мы тут помимо среднего также хотим посмотреть на стандартное отклонение
    # чтобы понять как сильно варьируются оценки моделей
    result = pd.DataFrame(index=labels)
    result['precision'] = fold_metrics[[f'precision_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['precision_std'] = fold_metrics[[f'precision_{i}' for i in range(N)]].std(axis=1).round(2)
    
    result['recall'] = fold_metrics[[f'recall_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['recall_std'] = fold_metrics[[f'recall_{i}' for i in range(N)]].std(axis=1).round(2)
    
    result['f1'] = fold_metrics[[f'f1_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['f1_std'] = fold_metrics[[f'f1_{i}' for i in range(N)]].std(axis=1).round(2)
    
    # добавим одну колонку со средним по всем классам
    result.loc['mean'] = result.mean().round(2)
    # проценты ошибок просто усредняем
    errors /= N
    
    return result, errors

# %% [markdown]
# #### Классификаторы с SVD

# %%
# Random forest
pipeline_svd_RF = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('svd', TruncatedSVD(500)),
    ('clf', RandomForestClassifier(n_estimators=100, max_depth=10))
])

# %%
# K-Neighbors
pipeline_svd_KNN = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('svd', TruncatedSVD(500)),
    ('clf', KNeighborsClassifier(n_neighbors=6))
])

# %%
# Extra Trees
pipeline_svd_X3 = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('svd', TruncatedSVD(500)),
    ('clf', ExtraTreesClassifier(random_state=0))
])

# %%
# SGD
pipeline_svd_SGD = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('svd', TruncatedSVD(500)),
    ('clf', SGDClassifier(max_iter=1000, tol=1e-3))
])

# %% [markdown]
# #### Классификаторы с NMF

# %%
# Random forest
pipeline_nmf_RF = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('decomposition', NMF(50)),
    ('clf', RandomForestClassifier(n_estimators=100, max_depth=10))
])

# %%
# K-Neighbors
pipeline_nmf_KNN = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('decomposition', NMF(50)),
    ('clf', KNeighborsClassifier(n_neighbors=6))
])

# %%
# Extra Trees
pipeline_nmf_X3 = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('decomposition', NMF(50)),
    ('clf', ExtraTreesClassifier(random_state=0))
])

# %%
# SGD
pipeline_nmf_SGD = Pipeline([
    ('bow', CountVectorizer(tokenizer=lambda x: x.split(), ngram_range=(1,2), min_df=5, max_df=0.4)),
    ('decomposition', NMF(50)),
    ('clf', SGDClassifier(max_iter=1000, tol=1e-3))
])

# %% [markdown]
# #### Random forest

# %%
metrics_svd_RF, errors_svd_RF = eval_table(data['description_norm'], data['category_name'], pipeline_svd_RF)

# %%
metrics_nmf_RF, errors_nmf_RF = eval_table(data['description_norm'], data['category_name'], pipeline_nmf_RF)

# %%
metrics_svd_RF
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.47           0.01    0.77        0.01
# Автомобили                       0.85           0.05    0.61        0.06
# Предложение услуг                0.74           0.06    0.46        0.04
# Квартиры                         0.88           0.02    0.89        0.03
# Мебель и интерьер                0.88           0.21    0.04        0.02
# Ремонт и строительство           0.71           0.11    0.09        0.03
# Товары для детей и игрушки       0.81           0.07    0.18        0.03
# Бытовая техника                  0.89           0.13    0.06        0.03
# Телефоны                         0.94           0.03    0.34        0.04
# Детская одежда и обувь           0.45           0.01    0.68        0.03
# mean                             0.76           0.07    0.41        0.03
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.58    0.01
# Автомобили                  0.70    0.04
# Предложение услуг           0.57    0.04
# Квартиры                    0.88    0.02
# Мебель и интерьер           0.07    0.04
# Ремонт и строительство      0.16    0.04
# Товары для детей и игрушки  0.29    0.04
# Бытовая техника             0.12    0.05
# Телефоны                    0.49    0.05
# Детская одежда и обувь      0.54    0.02
# mean                        0.44    0.04

# %%
metrics_nmf_RF
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.50           0.02    0.74        0.03
# Автомобили                       0.79           0.04    0.78        0.05
# Предложение услуг                0.67           0.04    0.64        0.02
# Квартиры                         0.94           0.02    0.93        0.03
# Мебель и интерьер                0.69           0.09    0.24        0.07
# Ремонт и строительство           0.67           0.08    0.23        0.04
# Товары для детей и игрушки       0.76           0.03    0.43        0.07
# Бытовая техника                  0.80           0.40    0.04        0.04
# Телефоны                         0.75           0.03    0.64        0.05
# Детская одежда и обувь           0.56           0.02    0.66        0.01
# mean                             0.71           0.08    0.53        0.04
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.60    0.02
# Автомобили                  0.78    0.03
# Предложение услуг           0.65    0.02
# Квартиры                    0.93    0.01
# Мебель и интерьер           0.35    0.08
# Ремонт и строительство      0.34    0.06
# Товары для детей и игрушки  0.54    0.06
# Бытовая техника             0.07    0.07
# Телефоны                    0.69    0.04
# Детская одежда и обувь      0.61    0.01
# mean                        0.56    0.04

# %%
metrics_svd_RF - metrics_nmf_RF
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары       -0.03          -0.01    0.03       -0.02
# Автомобили                       0.06           0.01   -0.17        0.01
# Предложение услуг                0.07           0.02   -0.18        0.02
# Квартиры                        -0.06           0.00   -0.04        0.00
# Мебель и интерьер                0.19           0.12   -0.20       -0.05
# Ремонт и строительство           0.04           0.03   -0.14       -0.01
# Товары для детей и игрушки       0.05           0.04   -0.25       -0.04
# Бытовая техника                  0.09          -0.27    0.02       -0.01
# Телефоны                         0.19           0.00   -0.30       -0.01
# Детская одежда и обувь          -0.11          -0.01    0.02        0.02
# mean                             0.05          -0.01   -0.12       -0.01
#
#                               f1  f1_std
# Одежда, обувь, аксессуары  -0.02   -0.01
# Автомобили                 -0.08    0.01
# Предложение услуг          -0.08    0.02
# Квартиры                   -0.05    0.01
# Мебель и интерьер          -0.28   -0.04
# Ремонт и строительство     -0.18   -0.02
# Товары для детей и игрушки -0.25   -0.02
# Бытовая техника             0.05   -0.02
# Телефоны                   -0.20    0.01
# Детская одежда и обувь     -0.07    0.01
# mean                       -0.12    0.00

# %% [markdown]
# Среди Random Forest классификаторов наиболее эффективным оказался классификатор **Random Forest с NMF**.

# %% [markdown]
# **KNeighborsClassifier**

# %%
metrics_svd_KNN, errors_svd_KNN = eval_table(data['description_norm'], data['category_name'], pipeline_svd_KNN)

# %%
metrics_nmf_KNN, errors_nmf_KNN = eval_table(data['description_norm'], data['category_name'], pipeline_nmf_KNN)

# %%
metrics_svd_KNN
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.46           0.02    0.55        0.03
# Автомобили                       0.57           0.04    0.59        0.03
# Предложение услуг                0.57           0.04    0.57        0.06
# Квартиры                         0.94           0.01    0.72        0.04
# Мебель и интерьер                0.35           0.06    0.25        0.05
# Ремонт и строительство           0.27           0.05    0.15        0.02
# Товары для детей и игрушки       0.51           0.04    0.23        0.03
# Бытовая техника                  0.31           0.06    0.27        0.10
# Телефоны                         0.70           0.10    0.31        0.04
# Детская одежда и обувь           0.47           0.01    0.66        0.03
# mean                             0.51           0.04    0.43        0.04
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.50    0.02
# Автомобили                  0.58    0.04
# Предложение услуг           0.57    0.04
# Квартиры                    0.82    0.02
# Мебель и интерьер           0.29    0.05
# Ремонт и строительство      0.19    0.02
# Товары для детей и игрушки  0.32    0.03
# Бытовая техника             0.28    0.08
# Телефоны                    0.43    0.05
# Детская одежда и обувь      0.55    0.01
# mean                        0.45    0.04

# %%
metrics_nmf_KNN
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.46           0.02    0.52        0.02
# Автомобили                       0.52           0.03    0.62        0.03
# Предложение услуг                0.58           0.02    0.60        0.04
# Квартиры                         0.92           0.02    0.83        0.05
# Мебель и интерьер                0.26           0.04    0.17        0.04
# Ремонт и строительство           0.38           0.07    0.19        0.04
# Товары для детей и игрушки       0.54           0.08    0.23        0.05
# Бытовая техника                  0.20           0.06    0.14        0.05
# Телефоны                         0.51           0.08    0.28        0.06
# Детская одежда и обувь           0.41           0.02    0.59        0.02
# mean                             0.48           0.04    0.42        0.04
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.49    0.01
# Автомобили                  0.57    0.03
# Предложение услуг           0.59    0.02
# Квартиры                    0.87    0.02
# Мебель и интерьер           0.20    0.04
# Ремонт и строительство      0.26    0.05
# Товары для детей и игрушки  0.32    0.06
# Бытовая техника             0.16    0.04
# Телефоны                    0.36    0.07
# Детская одежда и обувь      0.49    0.02
# mean                        0.43    0.04

# %%
metrics_svd_KNN - metrics_nmf_KNN
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.00           0.00    0.03        0.01
# Автомобили                       0.05           0.01   -0.03        0.00
# Предложение услуг               -0.01           0.02   -0.03        0.02
# Квартиры                         0.02          -0.01   -0.11       -0.01
# Мебель и интерьер                0.09           0.02    0.08        0.01
# Ремонт и строительство          -0.11          -0.02   -0.04       -0.02
# Товары для детей и игрушки      -0.03          -0.04    0.00       -0.02
# Бытовая техника                  0.11           0.00    0.13        0.05
# Телефоны                         0.19           0.02    0.03       -0.02
# Детская одежда и обувь           0.06          -0.01    0.07        0.01
# mean                             0.03           0.00    0.01        0.00
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.01    0.01
# Автомобили                  0.01    0.01
# Предложение услуг          -0.02    0.02
# Квартиры                   -0.05    0.00
# Мебель и интерьер           0.09    0.01
# Ремонт и строительство     -0.07   -0.03
# Товары для детей и игрушки  0.00   -0.03
# Бытовая техника             0.12    0.04
# Телефоны                    0.07   -0.02
# Детская одежда и обувь      0.06   -0.01
# mean                        0.02    0.00

# %% [markdown]
# Среди KNN классификаторов более эффективным оказался классификатор **KNN с SVD**.

# %% [markdown]
# **ExtraTreesClassifier**

# %%
metrics_svd_X3, errors_svd_X3 = eval_table(data['description_norm'], data['category_name'], pipeline_svd_X3)

# %%
metrics_nmf_X3, errors_nmf_X3 = eval_table(data['description_norm'], data['category_name'], pipeline_nmf_X3)

# %%
metrics_svd_X3
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.46           0.01    0.70        0.02
# Автомобили                       0.80           0.06    0.45        0.01
# Предложение услуг                0.88           0.09    0.28        0.06
# Квартиры                         0.72           0.04    0.80        0.05
# Мебель и интерьер                0.75           0.08    0.11        0.03
# Ремонт и строительство           0.62           0.17    0.09        0.04
# Товары для детей и игрушки       0.63           0.08    0.15        0.04
# Бытовая техника                  0.59           0.18    0.14        0.06
# Телефоны                         0.86           0.04    0.33        0.06
# Детская одежда и обувь           0.43           0.01    0.71        0.03
# mean                             0.67           0.08    0.38        0.04
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.56    0.01
# Автомобили                  0.58    0.01
# Предложение услуг           0.42    0.07
# Квартиры                    0.76    0.04
# Мебель и интерьер           0.20    0.05
# Ремонт и строительство      0.16    0.06
# Товары для детей и игрушки  0.25    0.05
# Бытовая техника             0.23    0.08
# Телефоны                    0.48    0.06
# Детская одежда и обувь      0.54    0.01
# mean                        0.42    0.04

# %%
metrics_nmf_X3
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.59           0.03    0.65        0.03
# Автомобили                       0.76           0.03    0.83        0.03
# Предложение услуг                0.68           0.04    0.74        0.06
# Квартиры                         0.93           0.02    0.95        0.02
# Мебель и интерьер                0.59           0.06    0.33        0.02
# Ремонт и строительство           0.52           0.05    0.33        0.07
# Товары для детей и игрушки       0.62           0.04    0.47        0.02
# Бытовая техника                  0.57           0.10    0.20        0.06
# Телефоны                         0.76           0.05    0.68        0.05
# Детская одежда и обувь           0.58           0.02    0.70        0.03
# mean                             0.66           0.04    0.59        0.04
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.62    0.02
# Автомобили                  0.79    0.01
# Предложение услуг           0.71    0.04
# Квартиры                    0.94    0.01
# Мебель и интерьер           0.42    0.03
# Ремонт и строительство      0.40    0.06
# Товары для детей и игрушки  0.53    0.03
# Бытовая техника             0.29    0.07
# Телефоны                    0.71    0.05
# Детская одежда и обувь      0.63    0.02
# mean                        0.60    0.03

# %%
metrics_svd_X3 - metrics_nmf_X3
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары       -0.13          -0.02    0.05       -0.01
# Автомобили                       0.04           0.03   -0.38       -0.02
# Предложение услуг                0.20           0.05   -0.46        0.00
# Квартиры                        -0.21           0.02   -0.15        0.03
# Мебель и интерьер                0.16           0.02   -0.22        0.01
# Ремонт и строительство           0.10           0.12   -0.24       -0.03
# Товары для детей и игрушки       0.01           0.04   -0.32        0.02
# Бытовая техника                  0.02           0.08   -0.06        0.00
# Телефоны                         0.10          -0.01   -0.35        0.01
# Детская одежда и обувь          -0.15          -0.01    0.01        0.00
# mean                             0.01           0.04   -0.21        0.00
#
#                               f1  f1_std
# Одежда, обувь, аксессуары  -0.06   -0.01
# Автомобили                 -0.21    0.00
# Предложение услуг          -0.29    0.03
# Квартиры                   -0.18    0.03
# Мебель и интерьер          -0.22    0.02
# Ремонт и строительство     -0.24    0.00
# Товары для детей и игрушки -0.28    0.02
# Бытовая техника            -0.06    0.01
# Телефоны                   -0.23    0.01
# Детская одежда и обувь     -0.09   -0.01
# mean                       -0.18    0.01

# %% [markdown]
# Среди ExtraTrees классификаторов более эффективным оказался классификатор **ExtraTrees с NMF**.

# %% [markdown]
# **SGD**

# %%
metrics_svd_SGD, errors_svd_SGD = eval_table(data['description_norm'], data['category_name'], pipeline_svd_SGD)

# %%
metrics_nmf_SGD, errors_nmf_SGD = eval_table(data['description_norm'], data['category_name'], pipeline_nmf_SGD)

# %%
metrics_svd_SGD
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.70           0.03    0.78        0.03
# Автомобили                       0.87           0.03    0.90        0.03
# Предложение услуг                0.77           0.03    0.75        0.02
# Квартиры                         0.95           0.02    0.96        0.02
# Мебель и интерьер                0.74           0.05    0.61        0.04
# Ремонт и строительство           0.58           0.06    0.50        0.07
# Товары для детей и игрушки       0.76           0.06    0.63        0.04
# Бытовая техника                  0.64           0.17    0.52        0.05
# Телефоны                         0.83           0.04    0.78        0.08
# Детская одежда и обувь           0.74           0.03    0.76        0.02
# mean                             0.76           0.05    0.72        0.04
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.74    0.01
# Автомобили                  0.89    0.02
# Предложение услуг           0.76    0.01
# Квартиры                    0.96    0.01
# Мебель и интерьер           0.67    0.04
# Ремонт и строительство      0.54    0.06
# Товары для детей и игрушки  0.69    0.03
# Бытовая техника             0.57    0.09
# Телефоны                    0.80    0.04
# Детская одежда и обувь      0.75    0.02
# mean                        0.74    0.03

# %%
metrics_nmf_SGD
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.47           0.09    0.76        0.11
# Автомобили                       0.77           0.11    0.71        0.07
# Предложение услуг                0.67           0.06    0.55        0.13
# Квартиры                         0.77           0.20    0.95        0.02
# Мебель и интерьер                0.39           0.15    0.17        0.08
# Ремонт и строительство           0.65           0.13    0.20        0.11
# Товары для детей и игрушки       0.67           0.16    0.41        0.06
# Бытовая техника                  0.50           0.21    0.08        0.04
# Телефоны                         0.76           0.17    0.39        0.11
# Детская одежда и обувь           0.52           0.09    0.40        0.17
# mean                             0.62           0.14    0.46        0.09
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.57    0.03
# Автомобили                  0.73    0.04
# Предложение услуг           0.60    0.08
# Квартиры                    0.84    0.13
# Мебель и интерьер           0.22    0.03
# Ремонт и строительство      0.29    0.14
# Товары для детей и игрушки  0.50    0.05
# Бытовая техника             0.13    0.07
# Телефоны                    0.49    0.06
# Детская одежда и обувь      0.42    0.07
# mean                        0.48    0.07

# %%
metrics_svd_SGD - metrics_nmf_SGD
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.23          -0.06    0.02       -0.08
# Автомобили                       0.10          -0.08    0.19       -0.04
# Предложение услуг                0.10          -0.03    0.20       -0.11
# Квартиры                         0.18          -0.18    0.01        0.00
# Мебель и интерьер                0.35          -0.10    0.44       -0.04
# Ремонт и строительство          -0.07          -0.07    0.30       -0.04
# Товары для детей и игрушки       0.09          -0.10    0.22       -0.02
# Бытовая техника                  0.14          -0.04    0.44        0.01
# Телефоны                         0.07          -0.13    0.39       -0.03
# Детская одежда и обувь           0.22          -0.06    0.36       -0.15
# mean                             0.14          -0.09    0.26       -0.05
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.17   -0.02
# Автомобили                  0.16   -0.02
# Предложение услуг           0.16   -0.07
# Квартиры                    0.12   -0.12
# Мебель и интерьер           0.45    0.01
# Ремонт и строительство      0.25   -0.08
# Товары для детей и игрушки  0.19   -0.02
# Бытовая техника             0.44    0.02
# Телефоны                    0.31   -0.02
# Детская одежда и обувь      0.33   -0.05
# mean                        0.26   -0.04

# %% [markdown]
# Среди SGD классификаторов более эффективным оказался классификатор **SGD с SVD**.

# %% [markdown]
# #### Полуфинал

# %%
metrics_svd_SGD-metrics_nmf_RF
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары        0.20           0.01    0.04        0.00
# Автомобили                       0.08          -0.01    0.12       -0.02
# Предложение услуг                0.10          -0.01    0.11        0.00
# Квартиры                         0.01           0.00    0.03       -0.01
# Мебель и интерьер                0.05          -0.04    0.37       -0.03
# Ремонт и строительство          -0.09          -0.02    0.27        0.03
# Товары для детей и игрушки       0.00           0.03    0.20       -0.03
# Бытовая техника                 -0.16          -0.23    0.48        0.01
# Телефоны                         0.08           0.01    0.14        0.03
# Детская одежда и обувь           0.18           0.01    0.10        0.01
# mean                             0.05          -0.03    0.19        0.00
#
#                               f1  f1_std
# Одежда, обувь, аксессуары   0.14   -0.01
# Автомобили                  0.11   -0.01
# Предложение услуг           0.11   -0.01
# Квартиры                    0.03    0.00
# Мебель и интерьер           0.32   -0.04
# Ремонт и строительство      0.20    0.00
# Товары для детей и игрушки  0.15   -0.03
# Бытовая техника             0.50    0.02
# Телефоны                    0.11    0.00
# Детская одежда и обувь      0.14    0.01
# mean                        0.18   -0.01

# %% [markdown]
# Классификатор **SGD с SVD** более эффективен, чем классификатор Random Forest с NMF.

# %%
metrics_svd_KNN-metrics_nmf_X3
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары       -0.13          -0.01   -0.10        0.00
# Автомобили                      -0.19           0.01   -0.24        0.00
# Предложение услуг               -0.11           0.00   -0.17        0.00
# Квартиры                         0.01          -0.01   -0.23        0.02
# Мебель и интерьер               -0.24           0.00   -0.08        0.03
# Ремонт и строительство          -0.25           0.00   -0.18       -0.05
# Товары для детей и игрушки      -0.11           0.00   -0.24        0.01
# Бытовая техника                 -0.26          -0.04    0.07        0.04
# Телефоны                        -0.06           0.05   -0.37       -0.01
# Детская одежда и обувь          -0.11          -0.01   -0.04        0.00
# mean                            -0.15           0.00   -0.16        0.00
#
#                               f1  f1_std
# Одежда, обувь, аксессуары  -0.12    0.00
# Автомобили                 -0.21    0.03
# Предложение услуг          -0.14    0.00
# Квартиры                   -0.12    0.01
# Мебель и интерьер          -0.13    0.02
# Ремонт и строительство     -0.21   -0.04
# Товары для детей и игрушки -0.21    0.00
# Бытовая техника            -0.01    0.01
# Телефоны                   -0.28    0.00
# Детская одежда и обувь     -0.08   -0.01
# mean                       -0.15    0.01

# %% [markdown]
# Классификатор KNN с SVD менее эффективен, чем классификатор **Extra Tress с NMF**.

# %% [markdown]
# #### Финал

# %%
metrics_nmf_X3-metrics_svd_SGD
# Out:
#                             precision  precision_std  recall  recall_std  \
# Одежда, обувь, аксессуары       -0.11           0.00   -0.13        0.00
# Автомобили                      -0.11           0.00   -0.07        0.00
# Предложение услуг               -0.09           0.01   -0.01        0.04
# Квартиры                        -0.02           0.00   -0.01        0.00
# Мебель и интерьер               -0.15           0.01   -0.28       -0.02
# Ремонт и строительство          -0.06          -0.01   -0.17        0.00
# Товары для детей и игрушки      -0.14          -0.02   -0.16       -0.02
# Бытовая техника                 -0.07          -0.07   -0.32        0.01
# Телефоны                        -0.07           0.01   -0.10       -0.03
# Детская одежда и обувь          -0.16          -0.01   -0.06        0.01
# mean                            -0.10          -0.01   -0.13        0.00
#
#                               f1  f1_std
# Одежда, обувь, аксессуары  -0.12    0.01
# Автомобили                 -0.10   -0.01
# Предложение услуг          -0.05    0.03
# Квартиры                   -0.02    0.00
# Мебель и интерьер          -0.25   -0.01
# Ремонт и строительство     -0.14    0.00
# Товары для детей и игрушки -0.16    0.00
# Бытовая техника            -0.28   -0.02
# Телефоны                   -0.09    0.01
# Детская одежда и обувь     -0.12    0.00
# mean                       -0.14    0.00

# %% [markdown]
# По итогам эксперимента самой эффективной моделью оказался классификатор **SGD с SVD**.

# %% [markdown]
# ### Задание № 2 (6 баллов)

# %%
otexts = open('wiki_data.txt','r', encoding = 'utf-8').read().splitlines()[:1000]

# %%
otexts[0]
# Out:
# '######Новостройка (Нижегородская область)############Новостро́йка — сельский посёлок в Дивеевском районе Нижегородской области. Входит в состав Сатисского сельсовета.############Посёлок расположен в 12,5 км к югу от села Дивеева и 1 км к западу от города Сарова, на правом берегу реки Вичкинза (правый приток реки Сатис). Окружён смешанными лесами. Соединён асфальтовой дорогой с посёлком Цыгановка (1,5 км) и грунтовыми просёлочными дорогами с посёлком Сатис (3,5 км). Название Новостройка является сугубо официальным, местное население использует исключительно альтернативное название — Хитрый. Употребляется языковой оборот «…на Хитром». Ранее используемые названия — Песчаный, Известковый.############Основан в 1920-х годах переселенцами из соседних сёл Аламасово и Нарышкино (расположенных соответственно в 8 и 14 км к западу в Вознесенском районе).############Традиционно в посёлке жили рабочие совхоза «Вперёд» (центр в посёлке Сатис). Возле посёлка расположен карьер где активно добывали доломитовую муку и бутовый камень (в настоящее время официально закрыт).############По данным 1978 года посёлок Новостройка характеризовался как неперспективный, здесь насчитывалось 24 хозяйства и 43 жителя. Водоснабжение осуществлялось из колодцев и родников, учреждения соцкультбыта отсутствовали. В 1992 году в посёлке насчитывалось 7 хозяйств и 16 жителей, из которых 7 трудоспособного возраста. На 1 января 1995 года в посёлке имелось 6 хозяйств и 12 жителей.############В настоящее время посёлок не только остаётся жилым, но и получил развитие благодаря своей близости к святым источникам. В полукилометре расположен Казанский родник, а в 1,2 км — источник святого Серафима Саровского.############В посёлке расположен скит Дивеевского монастыря.######В 2012 году был освящён домовой храм в честь Серафима Саровского.##############################'

# %%
texts = ([normalize(text) for text in otexts])

# %% [markdown]
# ### Без TF-IDF и n-граммов

# %%
dictinary = gensim.corpora.Dictionary((text.split() for text in texts))

# %%
dictinary.filter_extremes(no_above=0.1, no_below=10)
dictinary.compactify()

# %%
print(dictinary)
# Out:
# Dictionary(2301 unique tokens: ['1,5', '12', '14', '16', '1920-й']...)

# %%
corpus = [dictinary.doc2bow(text.split()) for text in texts]

# %%
lda = gensim.models.LdaMulticore(corpus, 
                                 100, # колиество тем
                                 alpha='asymmetric',
                                 id2word=dictinary, 
                                 passes=10) 
# если не поддерживается многопоточность
# lda = gensim.models.LdaModel(200, id2word=dictinary, passes=5)

# %%
lda.print_topics()[:10]
# Out:
# [(99,
#   '0.038*"италия" + 0.034*"рим" + 0.027*"1940" + 0.025*"март" + 0.018*"1941" + 0.018*"тип" + 0.017*"итальянский" + 0.017*"вступить" + 0.017*"исключить" + 0.016*"эсминец"'),
#  (97,
#   '0.032*"день" + 0.019*"дерево" + 0.019*"департамент" + 0.018*"форма" + 0.017*"участник" + 0.017*"северо-запад" + 0.014*"простой" + 0.014*"восток" + 0.013*"германия" + 0.013*"регион"'),
#  (98,
#   '0.055*"язык" + 0.043*"семейство" + 0.036*"1965" + 0.029*"остров" + 0.026*"распространение" + 0.023*"часто" + 0.019*"версия" + 0.017*"пара" + 0.017*"встречаться" + 0.017*"австралия"'),
#  (96,
#   '0.031*"памятник" + 0.018*"сад" + 0.017*"фон" + 0.016*"сопротивление" + 0.016*"германия" + 0.014*"университет" + 0.013*"северо-восточный" + 0.012*"степень" + 0.010*"установить" + 0.009*"мужчина"'),
#  (94,
#   '0.058*"музей" + 0.036*"здание" + 0.028*"художник" + 0.026*"искусство" + 0.022*"улица" + 0.020*"дом" + 0.018*"век" + 0.014*"произведение" + 0.014*"азербайджан" + 0.013*"среди"'),
#  (93,
#   '0.023*"южный" + 0.022*"тысяча" + 0.017*"общество" + 0.016*"экономический" + 0.016*"данные" + 0.015*"г" + 0.015*"тыс" + 0.012*"численность" + 0.012*"перепись" + 0.012*"2015"'),
#  (95,
#   '0.048*"церковь" + 0.036*"епархия" + 0.028*"храм" + 0.017*"православный" + 0.016*"епископ" + 0.013*"приход" + 0.012*"собор" + 0.011*"святой" + 0.011*"русский" + 0.011*"сооружение"'),
#  (92,
#   '0.034*"формат" + 0.029*"замок" + 0.022*"северный" + 0.021*"ирландия" + 0.016*"качество" + 0.015*"1920" + 0.013*"волость" + 0.012*"музыкальный" + 0.012*"1-й" + 0.012*"2-й"'),
#  (91,
#   '0.057*"значение" + 0.028*"британский" + 0.027*"сражение" + 0.024*"друг" + 0.022*"орден" + 0.017*"из-за" + 0.017*"битва" + 0.015*"матч" + 0.015*"ноябрь" + 0.015*"термин"'),
#  (90,
#   '0.101*"село" + 0.034*"г" + 0.022*"км" + 0.015*"киргизия" + 0.013*"практически" + 0.013*"температура" + 0.011*"сторона" + 0.011*"река" + 0.010*"август" + 0.010*"закон"')]

# %%
print("Перплексия:", "\n", np.exp2(-lda.log_perplexity(corpus[:1000])))
# Out:
# Перплексия:
#  214.93282684557354

# %%
topics = []
for topic_id, topic in lda.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics.append(topic)

# %%
coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                   texts=[text.split() for text in texts], 
                                                   dictionary=dictinary, coherence='c_v')

# %%
print("Когерентность:", "\n", coherence_model_lda.get_coherence())
# Out:
# Когерентность:
#  0.49362914937785335

# %% [markdown]
# ### C TF-IDF

# %%
dictinary1 = gensim.corpora.Dictionary((text.split() for text in texts))
dictinary1.filter_extremes(no_above=0.1, no_below=10)
dictinary1.compactify()

# %%
print(dictinary1)
# Out:
# Dictionary(2301 unique tokens: ['1,5', '12', '14', '16', '1920-й']...)

# %%
corpus1 = [dictinary1.doc2bow(text.split()) for text in texts]

# %%
tfidf = gensim.models.TfidfModel(corpus1, id2word=dictinary1)
corpus1 = tfidf[corpus1]

# %%
lda1 = gensim.models.LdaMulticore(corpus1, 
                                 100, # колиество тем
                                 alpha='asymmetric',
                                 id2word=dictinary1, 
                                 passes=10)

# %%
lda1.print_topics()[:10]
# Out:
# [(99,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (97,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (98,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (96,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (94,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (95,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (92,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (93,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (91,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (90,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"')]

# %%
print("Перплексия:", "\n", np.exp2(-lda1.log_perplexity(corpus[:1000])))
# Out:
# Перплексия:
#  546.8289615381884

# %%
topics1 = []
for topic_id, topic in lda1.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics1.append(topic)
    
coherence_model_lda1 = gensim.models.CoherenceModel(topics=topics1, 
                                                   texts=[text.split() for text in texts], 
                                                   dictionary=dictinary1, coherence='c_v')

# %%
print("Когерентность:", "\n", coherence_model_lda1.get_coherence())
# Out:
# Когерентность:
#  0.4211784760246522

# %% [markdown]
# ### C N-граммами

# %%
texts4ngrams = [text.split() for text in texts]
ph = gensim.models.Phrases(texts4ngrams, scoring='npmi', threshold=0.4) # threshold можно подбирать
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts = p[texts4ngrams]

# %%
dictinary2 = gensim.corpora.Dictionary((text for text in ngrammed_texts))
dictinary2.filter_extremes(no_above=0.1, no_below=10)
dictinary2.compactify()

# %%
corpus2 = [dictinary2.doc2bow(text) for text in ngrammed_texts]

# %%
lda2 = gensim.models.LdaMulticore(corpus2, 
                                 100, # колиество тем
                                 alpha='asymmetric',
                                 id2word=dictinary2, 
                                 passes=10)

# %%
lda2.print_topics()[:10]
# Out:
# [(99,
#   '0.040*"сезон" + 0.032*"клуб" + 0.021*"занять" + 0.020*"гонка" + 0.015*"чемпионат_мир" + 0.015*"выиграть" + 0.013*"контракт" + 0.012*"завоевать" + 0.011*"мир" + 0.010*"победа"'),
#  (96,
#   '0.040*"длина" + 0.033*"смотреть" + 0.030*"лист" + 0.027*"мм" + 0.024*"вид" + 0.012*"я" + 0.012*"молодой" + 0.011*"ты" + 0.011*"семейство" + 0.011*"северный_америка"'),
#  (98,
#   '0.035*"–" + 0.022*"село" + 0.021*"пункт" + 0.020*"солдат" + 0.016*"сельский_поселение" + 0.015*"фильм" + 0.014*"на_территория" + 0.014*"железнодорожный" + 0.013*"поселение" + 0.012*"россия"'),
#  (97,
#   '0.053*"символ" + 0.021*"значение" + 0.020*"содержать" + 0.020*"s" + 0.018*"тема" + 0.016*"a" + 0.016*"термин" + 0.015*"x" + 0.013*"канада" + 0.012*"серебряный"'),
#  (95,
#   '0.018*"университет" + 0.015*"книга" + 0.014*"знание" + 0.014*"животное" + 0.010*"себя" + 0.010*"наука" + 0.010*"научный" + 0.008*"деятельность" + 0.008*"общество" + 0.007*"язык"'),
#  (92,
#   '0.096*"сельский_поселение" + 0.054*"поселение" + 0.050*"№" + 0.040*"закон" + 0.029*"1_январь" + 0.026*"посёлок" + 0.025*"иметься" + 0.021*"лесной" + 0.021*"территория" + 0.021*"население"'),
#  (93,
#   '0.013*"клуб" + 0.013*"система" + 0.012*"линия" + 0.012*"городской" + 0.012*"г" + 0.008*"ряд" + 0.008*"20" + 0.008*"дело" + 0.007*"путь" + 0.007*"провести"'),
#  (94,
#   '0.019*"выжить" + 0.019*"самолёт" + 0.018*"погибнуть" + 0.017*"пассажир" + 0.015*"день" + 0.014*"умереть" + 0.011*"путь" + 0.011*"пилот" + 0.010*"декабрь" + 0.010*"святой"'),
#  (91,
#   '0.020*"заключить" + 0.019*"роман" + 0.017*"лагерь" + 0.014*"здание" + 0.010*"выйти" + 0.010*"архитектор" + 0.010*"предложить" + 0.009*"священник" + 0.009*"французский" + 0.008*"снятой"'),
#  (90,
#   '0.051*"доктор" + 0.017*"серия" + 0.011*"жизнь" + 0.010*"себя" + 0.008*"чтобы" + 0.008*"эпизод" + 0.008*"роль" + 0.007*"ребёнок" + 0.007*"друг" + 0.007*"возраст"')]

# %%
print("Перплексия:", "\n", np.exp2(-lda2.log_perplexity(corpus2[:1000])))
# Out:
# Перплексия:
#  264.52880081056134

# %%
topics2 = []
for topic_id, topic in lda2.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics2.append(topic)

# %%
coherence_model_lda2 = gensim.models.CoherenceModel(topics=topics2, 
                                                   texts=[text.split() for text in texts], 
                                                   dictionary=dictinary, coherence='c_v')

# %%
print("Когерентность:", "\n", coherence_model_lda2.get_coherence())
# Out:
# Когерентность:
#  0.4920089611600607

# %% [markdown]
# ### C TF-IDF и n-граммами

# %%
dictinary3 = gensim.corpora.Dictionary((text for text in ngrammed_texts))
dictinary3.filter_extremes(no_above=0.1, no_below=10)
dictinary3.compactify()

# %%
corpus3 = [dictinary3.doc2bow(text) for text in ngrammed_texts]

# %%
tfidf = gensim.models.TfidfModel(corpus3, id2word=dictinary3)
corpus3 = tfidf[corpus3]

# %%
lda3 = gensim.models.LdaMulticore(corpus3, 
                                 100, # колиество тем
                                 alpha='asymmetric',
                                 id2word=dictinary3, 
                                 passes=10)
# %time
# Out:
# Wall time: 0 ns

# %%
lda3.print_topics()[:10]
# Out:
# [(98,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (99,
#   '0.000*"база" + 0.000*"тип" + 0.000*"эсминец" + 0.000*"эксплуатация" + 0.000*"честь" + 0.000*"американский" + 0.000*"1983" + 0.000*"1984" + 0.000*"ввести" + 0.000*"согласно"'),
#  (97,
#   '0.002*"священник" + 0.001*"убивать" + 0.001*"пол" + 0.001*"местный_житель" + 0.001*"решать" + 0.000*"пытаться" + 0.000*"начинать" + 0.000*"церковь" + 0.000*"вариант" + 0.000*"здание"'),
#  (96,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (94,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (95,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (93,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (92,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (91,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (90,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"')]

# %%
print("Перплексия:", "\n", np.exp2(-lda3.log_perplexity(corpus3[:1000])))
# Out:
# Перплексия:
#  12056.535885954205

# %%
topics3 = []
for topic_id, topic in lda3.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics3.append(topic)

# %%
coherence_model_lda3 = gensim.models.CoherenceModel(topics=topics3, 
                                                   texts=[text.split() for text in texts], 
                                                   dictionary=dictinary, coherence='c_v')

# %%
print("Когерентность:", "\n", coherence_model_lda3.get_coherence())
# Out:
# Когерентность:
#  0.3750193299910641

# %% [markdown]
# Как можно видеть, модели с tf-idf показывают очень высокую перплексию - скорее всего в коде ошибка, из-за чего модели и дают такой результат. Тем не менее модель без n-граммов и tf-idf показывает самую низкую перплексию, при этом её результаты когерентности схожи с таковыми у модели с n-граммами; обе модели дают достаточно осмысленные и логичные темы.

# %% [markdown]
# ### Самые красивые темы

# %% [markdown]
# #### Без tf-idf и n-граммов

# %% [raw]
# (99
# '0.038*"италия" + 0.034*"рим" + 0.027*"1940" + 0.025*"март" + 0.018*"1941" + 0.018*"тип" + 0.017*"итальянский" + 0.017*"вступить" + 0.017*"исключить" + 0.016*"эсминец"'),

# %% [markdown]
# #### С tf-idf
# (здесь выбор был небольшой)

# %% [raw]
# (91,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"')

# %% [markdown]
# #### С n-граммами

# %% [raw]
# (90,
#   '0.051*"доктор" + 0.017*"серия" + 0.011*"жизнь" + 0.010*"себя" + 0.008*"чтобы" + 0.008*"эпизод" + 0.008*"роль" + 0.007*"ребёнок" + 0.007*"друг" + 0.007*"возраст"')]

# %% [markdown]
# #### С tf-idf и n-граммами
# (тоже небогатый выбор)

# %% [raw]
# (97,
#   '0.002*"священник" + 0.001*"убивать" + 0.001*"пол" + 0.001*"местный_житель" + 0.001*"решать" + 0.000*"пытаться" + 0.000*"начинать" + 0.000*"церковь" + 0.000*"вариант" + 0.000*"здание"'),
